# %% [markdown]
# <a href="https://colab.research.google.com/github/SeeratSandha/TriCheck-Triangle-TypeExplorer/blob/main/TriCheck%3A%20Triangle%20Type%20Explorer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Name of Assignment :  The Triangle Tester .
#Submitted by : Seerat Sandha .
#                               ........HOW MY PROGRAM WORKS.......
# In This assignment I will ask user to enter three random sides of triangle. Then my programme will output tnhe user that the sides
# are belong to which triangle (Type of Triangle). After that My programme will output that Triangle is Either Acute, Obtuse or Right- Angled
#After that, (While loop) inside programme,ables the user to take multiple number of  checks as long as user wants.
#Moreover, User can Quit the Checks by typing (VALUE OF PI:)= 3.14 in the First Box.


print("ALERT!! Your input should be positive integers. ")
print();
try:
 a =  int  (input("Enter The First Side of Triangle  :"+"\n"))
except:
  print("No, I asked for three numbers. Please!! Restart the program or type carefully in your 2nd check")

try:
 b = int  (input("Enter The Second Side of Triangle  :"+"\n"))
except:
  print("No, I asked for three numbers. Please!! Restart the program or type carefully in your 2nd check")
try:
 c = int  (input("Enter The Third  Side of Triangle  :"+"\n"))
except:
  print("No, I asked for three numbers. Please!! Restart the program or type carefully in your 2nd check")



if(a==0):

    print("Your numbers are not the sides of any triangle because your input is Zero .Here, ZERO results to an Degenerate Triangle.")


elif(a<=0):

    print("Your numbers are not the sides of any triangle because your input is of Negative type." )

elif(b==0):

    print("Your numbers are not the sides of any triangle because your input is Zero .Here, ZERO results to an Degenerate Triangle.")


elif(b<=0):

     print("Your numbers are not the sides of any triangle because your input is of Negative type.")

elif(c==0):

     print("Your numbers are not the sides of any triangle because your input is Zero .Here, ZERO results to an Degenerate Triangle.")


elif(c<=0):

      print("Your numbers are not the sides of any triangle because your input is of Negative type.")


if a==b and a==c and b==c:

      print("Your numbers are the sides of an equilateral triangle")

elif a==b or a==c or b==c :

         print("Your numbers are the sides of an isosceles triangle")

elif a!=b and a!=c and b!=c:


     print("Your numbers are the sides of a triangle with three different side lengths")

if(a>b and a>c):

    x=a
    y=b
    z=c

elif(b>a and  b>c):

    x=b
    y=a
    z=c

elif(c>a and c>b):

      x=c
      y=a
      z=b


if (x**2) ==(y**2) + (z**2):

       print("The Triangle is Right-Angled Triangle .")

elif((x**2) > (y**2) + (z**2)):

       print("The Triangle is Obtuse Triangle .")

elif((x**2) < (y**2) + (z**2)):

     print("The Triangle is Acute Triangle .")
else:
  print("Sorry!! Your sides cannot make a Triangle.")

while a!=int:
 print("\n"+"\n"+"  *******************************************You Can Check it as many times you want *************************************"+"\n")
 print("........................ IF YOU WANT TO QUIT CHECKS THEN TYPE :   '3.14' in FIRST BOX................................................"+"\n")

 a = float (input("Enter The First Side of Triangle  :"+"\n"))
 if(a==3.14) :
   print("                                               You Quit Successfully!!!                     ")
   break

 b = int (input("Enter The Second Side of Triangle  :"+"\n"))
 c = int (input("Enter The Third  Side of Triangle  :"+"\n"))
 if(a==3.14) :
      break

 elif(a==0):

    print("Your numbers are not the sides of any triangle because your input is Zero .Here, ZERO results to an Degenerate Triangle.")


 elif(a<=0):

    print("Your numbers are not the sides of any triangle because your input is of Negative type." )

 elif(b==0):

    print("Your numbers are not the sides of any triangle because your input is Zero .Here, ZERO results to an Degenerate Triangle.")


 elif(b<=0):

     print("Your numbers are not the sides of any triangle because your input is of Negative type.")

 elif(c==0):

     print("Your numbers are not the sides of any triangle because your input is Zero .Here, ZERO results to an Degenerate Triangle.")


 elif(c<=0):

      print("Your numbers are not the sides of any triangle because your input is of Negative type.")



 if a==b and a==c and b==c:

      print("Your numbers are the sides of an equilateral triangle")

 elif a==b or a==c or b==c:

        print("Your numbers are the sides of an isosceles triangle")

 elif a!=b!=c:

     print("Your numbers are the sides of a triangle with three different side lengths")

 if(a>b and a>c):

    x=a
    y=b
    z=c

 elif(b>a and  b>c):

    x=b
    y=a
    z=c

 elif(c>a and c>b):

      x=c
      y=a
      z=b

 if (x**2) ==(y**2) + (z**2):

       print("The Triangle is Right-Angled Triangle ."+"\n")

 elif((x**2) > (y**2) + (z**2)):

       print("The Triangle is Obtuse Triangle ."+"\n")

 elif((x**2) < (y**2) + (z**2)):

     print("The Triangle is Acute Triangle ."+"\n")


#              ................HOW I TESTED MY PROGRAM....................
# Firstly, When user enter the input inside the Displayed Input Boxes then , my If and ELif Statements gets Executed according to their Conditions
# After, Execution the Print statement inside the If & Elif Statements Print the content as output.
#Then , While loop Executed and ask the  user Multiple Times to Enter the Sides for Triangle Test.
# But, User can Quit the Programm When user desire, By entering the "value of PI" :  3.14.
# my programm provide Accurate output on Each Check.
#SO, This is all about my Programm.
# Thanks, Seerat Sandha.
# Out:
# ALERT!! Your input should be positive integers.
#
# Enter The First Side of Triangle  :
# 8
# Enter The Second Side of Triangle  :
# 2
# Enter The Third  Side of Triangle  :
# 3
# Your numbers are the sides of a triangle with three different side lengths
# The Triangle is Obtuse Triangle .
#
#
#   *******************************************You Can Check it as many times you want *************************************
#
# ........................ IF YOU WANT TO QUIT CHECKS THEN TYPE :   '3.14' in FIRST BOX................................................
#
# Enter The First Side of Triangle  :
# 4
# Enter The Second Side of Triangle  :
# 5
# Enter The Third  Side of Triangle  :
# 6
# Your numbers are the sides of a triangle with three different side lengths
# The Triangle is Acute Triangle .
#
#
#
#   *******************************************You Can Check it as many times you want *************************************
#
# ...
